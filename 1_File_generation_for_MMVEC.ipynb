# %%
library(phyloseq)
library(ggplot2)
library(vegan)
library(readr)
library(data.table)
library(dplyr)
library(stats)
library(ggpubr)
library(dunn.test)

# %%
alz_nt = readRDS("/projects/gilbert_lab/Lutz/Alzheimers/Update_Oct2019/PS_for_analysis/alz_nt.rds")
alz_nt.df = data.frame(sample_data(alz_nt))
head(alz_nt.df$Treatment)
head(alz_nt.df$Sex)
# Out:
# [1] Abx_FMT Abx     Abx     Control Control Control
# Levels: Abx Abx_FMT Control
# [1] M F M M F F
# Levels: F M

# %%
sample_data(alz_nt)
# Out:
#                 X.SampleID      Barcode      LinkerPrimerSequence  Well
# X17             X17             GCATATGCACTG GTGTGYCAGCMGCCGCGGTAA D5
# X5.F.7.Abx      X5.F.7.Abx      AATAACTAGGGT GTGTGYCAGCMGCCGCGGTAA D11
# X2.M.1.Abx      X2.M.1.Abx      ACTACTGAGGAT GTGTGYCAGCMGCCGCGGTAA A11
# X9              X9              CATTTCGCACTT GTGTGYCAGCMGCCGCGGTAA C9
# X4.F.7.ctr      X4.F.7.ctr      ACCTTACACCTT GTGTGYCAGCMGCCGCGGTAA D2
# X4.F.1.Ctr      X4.F.1.Ctr      AAGAACTCATGA GTGTGYCAGCMGCCGCGGTAA C6
# X7              X7              AGATCGTGCCTA GTGTGYCAGCMGCCGCGGTAA C7
# X5.F.5.Abx      X5.F.5.Abx      AATCTTGCGCCG GTGTGYCAGCMGCCGCGGTAA D9
# X13             X13             TCGTTATTCAGT GTGTGYCAGCMGCCGCGGTAA D1
# X2.M.7.Abx      X2.M.7.Abx      CGTCCGTATGAA GTGTGYCAGCMGCCGCGGTAA B5
# X16             X16             AGCAGTGCGGTG GTGTGYCAGCMGCCGCGGTAA D4
# X14             X14             GGATACTCGCAT GTGTGYCAGCMGCCGCGGTAA D2
# ...

# %%
Male = subset_samples(alz_nt, Sex=="M")
Male = subset_samples(Male, SampleType=="Fecal")
M_Ctrl = subset_samples(Male, Treatment=="Control")
M_Abx = subset_samples(Male, Treatment=="Abx")
M_AbxFmt = subset_samples(Male, Treatment=="Abx_FMT")

# %%
M_ALL = merge_phyloseq(M_Ctrl,M_Abx,M_AbxFmt)
M_ALL.otu = data.frame(otu_table(M_ALL))
M_ALL.meta = data.frame(sample_data(M_ALL))

write.csv(M_ALL.otu, "/home/holutz/projects/Alzheimers/mmvec_Feb2021/OTU_tables/M_ALL.otu.csv")
write.csv(M_ALL.meta, "/home/holutz/projects/Alzheimers/mmvec_Feb2021/OTU_tables/M_ALL.meta.csv")

# %%
M_Ctrl.otu = data.frame(otu_table(M_Ctrl))
M_Abx.otu = data.frame(otu_table(M_Abx))
M_AbxFmt.otu = data.frame(otu_table(M_AbxFmt))

write.csv(M_Ctrl.otu, "/home/holutz/projects/Alzheimers/mmvec_Feb2021/OTU_tables/M_Ctrl.otu.csv")
write.csv(M_Abx.otu, "/home/holutz/projects/Alzheimers/mmvec_Feb2021/OTU_tables/M_Abx.otu.csv")
write.csv(M_AbxFmt.otu, "/home/holutz/projects/Alzheimers/mmvec_Feb2021/OTU_tables/M_AbxFmt.otu.csv")

# %%
M_Ctrl.meta = data.frame(sample_data(M_Ctrl))
M_Abx.meta = data.frame(sample_data(M_Abx))
M_AbxFmt.meta = data.frame(sample_data(M_AbxFmt))

write.csv(M_Ctrl.meta, "/home/holutz/projects/Alzheimers/mmvec_Feb2021/OTU_tables/M_Ctrl.meta.csv")
write.csv(M_Abx.meta, "/home/holutz/projects/Alzheimers/mmvec_Feb2021/OTU_tables/M_Abx.meta.csv")
write.csv(M_AbxFmt.meta, "/home/holutz/projects/Alzheimers/mmvec_Feb2021/OTU_tables/M_AbxFmt.meta.csv")
